# %%
import pandas as pd

# %%
os.chdir('C:\\Users\\Zain Ahmed\\Desktop\\Literature review\\MetroData')

# %%
csvs = os.listdir()
csvs
# Out:
# ['en_climate_hourly_NL_8403505_01-2016_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2017_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2018_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2019_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2020_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2021_P1H.csv',
#  'en_climate_hourly_NL_8403505_01-2022_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2016_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2017_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2018_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2019_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2020_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2021_P1H.csv',
#  'en_climate_hourly_NL_8403505_02-2022_P1H.csv',
#  'en_climate_hourly_NL_8403505_03-2016_P1H.csv',
#  'en_climate_hourly_NL_8403505_03-2017_P1H.csv',
#  'en_climate_hourly_NL_8403505_03-2018_P1H.csv',
#  'en_climate_hourly_NL_8403505_03-2019_P1H.csv',
#  'en_climate_hourly_NL_8403505_03-2020_P1H.csv',
# ...

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in csvs])

# %%
combined_csv
# Out:
#      Longitude (x)  Latitude (y)       Station Name  Climate ID  \
# 0           -52.75         47.62  ST. JOHN'S INTL A     8403505
# 1           -52.75         47.62  ST. JOHN'S INTL A     8403505
# 2           -52.75         47.62  ST. JOHN'S INTL A     8403505
# 3           -52.75         47.62  ST. JOHN'S INTL A     8403505
# 4           -52.75         47.62  ST. JOHN'S INTL A     8403505
# ..             ...           ...                ...         ...
# 739         -52.75         47.62  ST. JOHN'S INTL A     8403505
# 740         -52.75         47.62  ST. JOHN'S INTL A     8403505
# 741         -52.75         47.62  ST. JOHN'S INTL A     8403505
# 742         -52.75         47.62  ST. JOHN'S INTL A     8403505
# 743         -52.75         47.62  ST. JOHN'S INTL A     8403505
#
#       Date/Time (LST)  Year  Month  Day Time (LST)  Temp (°C)  ...  \
# 0    2016-01-01 00:30  2016      1    1      00:30       -2.2  ...
# ...

# %%
os.chdir('C:\\Users\\Zain Ahmed\\Desktop\\Literature review\\Project Folder')

# %%
combined_csv['datetime'] = pd.to_datetime(combined_csv['Date/Time (LST)'],format='%Y-%m-%d %H:%M')

# %%
combined_csv = combined_csv.set_index('datetime')

# %%
combined_csv
# Out:
#                      Longitude (x)  Latitude (y)       Station Name  \
# datetime
# 2016-01-01 00:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2016-01-01 01:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2016-01-01 02:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2016-01-01 03:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2016-01-01 04:30:00         -52.75         47.62  ST. JOHN'S INTL A
# ...                            ...           ...                ...
# 2022-12-31 19:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2022-12-31 20:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2022-12-31 21:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2022-12-31 22:30:00         -52.75         47.62  ST. JOHN'S INTL A
# 2022-12-31 23:30:00         -52.75         47.62  ST. JOHN'S INTL A
#
#                      Climate ID   Date/Time (LST)  Year  Month  Day  \
# datetime
# ...

# %%
combined_csv.to_csv('metro_data.csv')
